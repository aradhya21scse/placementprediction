# %%
import numpy as np

# %%
import pandas as pd

# %%
data=pd.read_csv("placement.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
data.shape
# Out:
# (100, 4)

# %%
data.tail()
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.2 KB

# %%
data.describe()
# Out:
#        Unnamed: 0        cgpa          iq   placement
# count  100.000000  100.000000  100.000000  100.000000
# mean    49.500000    5.991000  123.580000    0.500000
# std     29.011492    1.143634   39.944198    0.502519
# min      0.000000    3.300000   37.000000    0.000000
# 25%     24.750000    5.075000  101.500000    0.000000
# 50%     49.500000    6.000000  127.500000    0.500000
# 75%     74.250000    6.900000  149.000000    1.000000
# max     99.000000    8.500000  233.000000    1.000000

# %%
data=data.iloc[:,1:]

# %%
data
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data['cgpa'],data["iq"],c=data["placement"])

# %%
x=data.iloc[:,0:2]
y=data.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
x.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 24   4.7  121.0
# 27   6.0  124.0
# 84   5.7  169.0
# 52   7.0  175.0
# 74   6.7  154.0
# ..   ...    ...
# 29   7.0  112.0
# 57   6.5  130.0
# 41   5.4  114.0
# 81   5.4  107.0
# 16   5.2  224.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 24    0
# 27    1
# 84    0
# 52    1
# 74    1
#      ..
# 29    1
# 57    1
# 41    0
# 81    0
# 16    0
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 34   4.8  163.0
# 70   6.3  127.0
# 68   4.0   75.0
# 69   8.5  120.0
# 48   6.6  138.0
# 6    5.7  143.0
# 89   4.9  151.0
# 28   5.2   90.0
# 92   5.2  110.0
# 79   6.5   90.0

# %%
y_test
# Out:
# 34    0
# 70    1
# 68    0
# 69    1
# 48    1
# 6     0
# 89    0
# 28    0
# 92    0
# 79    1
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-1.16635586e+00, -7.09798362e-02],
#        [-1.37913700e-02,  2.44758056e-03],
#        [-2.79767791e-01,  1.10385883e+00],
#        [ 8.72796700e-01,  1.25071367e+00],
#        [ 6.06820279e-01,  7.36721748e-01],
#        [-1.87562632e+00, -3.64689503e-01],
#        [ 9.61455507e-01,  6.63294331e-01],
#        [ 7.84137893e-01,  3.45108859e-01],
#        [ 1.31609073e+00, -1.53952817e+00],
#        [-1.07769705e+00,  1.10385883e+00],
#        [ 1.84804358e+00,  1.03043142e+00],
#        [ 9.61455507e-01, -1.85771364e+00],
#        [-8.11720633e-01, -1.41714914e+00],
#        [ 1.13877312e+00, -9.27633032e-01],
#        [-1.37913700e-02,  6.14342720e-01],
#        [-1.43233228e+00, -2.00456848e+00],
#        [ 3.40843858e-01,  4.18536276e-01],
#        [ 7.48674370e-02, -1.05001206e+00],
#        [ 1.13877312e+00, -1.93358864e-01],
#        [ 6.95479086e-01,  4.18536276e-01],
#        [-1.37913700e-02, -1.41714914e+00],
#        [ 4.29502665e-01,  8.83576582e-01],
#        [-5.45744212e-01,  3.69584664e-01],
#        [-1.52099109e+00,  1.86260881e+00],
#        [-1.43233228e+00,  6.14342720e-01],
#        [ 6.06820279e-01,  1.42204430e+00],
#        [ 8.72796700e-01,  1.83813300e+00],
#        [ 7.48674370e-02,  1.98254025e-01],
#        [ 6.95479086e-01, -2.20282250e-02],
#        [-1.07769705e+00,  4.18536276e-01],
#        [-5.45744212e-01,  2.71681442e-01],
#        [ 2.52185051e-01, -5.11544337e-01],
#        [ 2.52185051e-01,  1.00350803e-01],
#        [-9.89038247e-01, -1.53952817e+00],
#        [-9.00379440e-01, -1.44407253e-01],
#        [-1.37913700e-02, -5.36020142e-01],
#        [ 4.29502665e-01, -2.12694751e+00],
#        [-9.89038247e-01,  1.76470558e+00],
#        [ 1.22743193e+00,  1.98254025e-01],
#        [-1.16635586e+00, -1.75981042e+00],
#        [-2.40757916e+00,  1.44652011e+00],
#        [-2.79767791e-01,  1.98254025e-01],
#        [ 3.40843858e-01, -1.93358864e-01],
#        [-1.16635586e+00, -9.03157226e-01],
#        [ 1.40474954e+00, -8.54205615e-01],
#        [-6.34403019e-01, -7.09798362e-02],
#        [ 1.31609073e+00,  8.34624971e-01],
#        [-7.23061826e-01,  1.98254025e-01],
#        [ 1.40474954e+00,  1.00350803e-01],
#        [ 7.48674370e-02,  7.85673359e-01],
#        [ 1.84804358e+00,  6.14342720e-01],
#        [ 5.18161472e-01, -9.54556418e-02],
#        [-2.79767791e-01,  3.94060470e-01],
#        [ 6.95479086e-01, -2.91262086e-01],
#        [-9.00379440e-01, -8.05254004e-01],
#        [-1.07769705e+00, -2.91262086e-01],
#        [-7.23061826e-01,  9.08052387e-01],
#        [-1.91108984e-01,  4.43012081e-01],
#        [-1.91108984e-01,  1.03043142e+00],
#        [-9.89038247e-01, -9.54556418e-02],
#        [ 8.72796700e-01,  3.69584664e-01],
#        [-8.11720633e-01,  1.00350803e-01],
#        [ 6.95479086e-01, -8.29729809e-01],
#        [ 8.72796700e-01, -1.46610075e+00],
#        [ 1.31609073e+00,  1.49302414e-01],
#        [ 1.13877312e+00, -1.80876203e+00],
#        [-1.37913700e-02, -1.93114106e+00],
#        [-2.23026154e+00,  2.67031039e+00],
#        [ 7.84137893e-01, -6.82874976e-01],
#        [ 1.13877312e+00,  3.20633053e-01],
#        [ 2.02536119e+00,  1.07938303e+00],
#        [-9.89038247e-01,  2.47205636e-01],
#        [ 1.63526244e-01, -2.66786281e-01],
#        [-8.11720633e-01,  1.27518947e+00],
#        [-1.02450177e-01, -4.38116920e-01],
#        [-1.78696751e+00, -5.84971754e-01],
#        [ 1.58206716e+00, -2.42310475e-01],
#        [ 7.48674370e-02, -1.44162495e+00],
#        [ 1.75938477e+00, -1.09896367e+00],
#        [-1.25501467e+00,  5.40915303e-01],
#        [ 7.84137893e-01,  3.69584664e-01],
#        [ 7.48674370e-02, -5.11544337e-01],
#        [-6.34403019e-01, -2.42310475e-01],
#        [-9.00379440e-01, -1.49057656e+00],
#        [-9.89038247e-01,  7.61197554e-01],
#        [ 8.72796700e-01, -2.91262086e-01],
#        [ 4.29502665e-01,  1.49302414e-01],
#        [-5.45744212e-01, -2.42310475e-01],
#        [-5.45744212e-01, -4.13641114e-01],
#        [-7.23061826e-01,  2.45002814e+00]])

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[-1.07769705,  0.957004  ],
#        [ 0.25218505,  0.075875  ],
#        [-1.78696751, -1.19686689],
#        [ 2.2026788 , -0.09545564],
#        [ 0.51816147,  0.34510886],
#        [-0.27976779,  0.46748789],
#        [-0.98903825,  0.66329433],
#        [-0.72306183, -0.82972981],
#        [-0.72306183, -0.3402137 ],
#        [ 0.42950266, -0.82972981]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
a=clf.fit(x_train,y_train)

# %%
y_pred=clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open("model.pkl","wb"))
